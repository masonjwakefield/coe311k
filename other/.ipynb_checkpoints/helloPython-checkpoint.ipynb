# %% [markdown]
# Hello Python! This is my very first notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(True)
# Out:
# True

# %%
print(2+2)
# Out:
# 4

# %%
print("Hello class")
print("TACC's awesome")
# Out:
# Hello class
# TACC's awesome

# %%
a = 67
b = "Hello"
c = True

# %%
myfile = open("test.dat",'w')
myfile.write(str(2+2))
myfile.write("Hello World")
myfile.close()

# %%
a=2
b=3
print(a==b or a<b)
# Out:
# True

# %%
for i in range(1, 4):
    for j in range(2, 5):
        print(i,j)
# Out:
# 1 2
# 1 3
# 1 4
# 2 2
# 2 3
# 2 4
# 3 2
# 3 3
# 3 4

# %%
mylist = ["diddy","foid"]
print(mylist)
# Out:
# ['diddy', 'foid']
