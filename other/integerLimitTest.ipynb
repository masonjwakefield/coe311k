# %%
for i in range (0,1000):
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-27de248af18f> in <module>
# ----> 1 [...
#
# NameError: name 'integerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerintegerinte' is not defined
