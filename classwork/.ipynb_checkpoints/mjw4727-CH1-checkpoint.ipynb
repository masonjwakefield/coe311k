# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-100, 100, 21)
y = x*x

# %%
plt.subplot(2, 2, 1)
plt.scatter(x, y)
plt.subplot(2, 2, 2)
plt.plot(x, y, 'r')
plt.subplot(2, 2, 3)
plt.plot(y, x, 'g')
plt.subplot(2, 2, 4)
plt.plot(-y, x, 'y')
