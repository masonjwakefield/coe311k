# %% [markdown]
# libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %% [markdown]
# data set

# %%
# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

# %% [markdown]
# polynomial calculations

# %%
# Fit a 3rd degree polynomial to the data
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)
polynomial = np.poly1d(coefficients)

# Generate new values for a smooth plot
x_pred = np.linspace(0, 5, 100)
y_pred = polynomial(x_pred)

# %% [markdown]
# cubic spline calculations

# %%
# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')

# Generate new x values for a smooth plot
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

# %% [markdown]
# plotting both

# %%
# Plotting points
plt.scatter(x, y, color = 'red') # Original data points

# Plotting polynomial fit of degree 3
plt.plot(x_pred, y_pred, color='green', label=f'Polynomial fit of degree {degree}')

# Plotting cubic spline interpolation
plt.plot(x_interp, y_interp, 'blue', label='Cubic Spline')

# Polishing plot
plt.title('Polynomial Fit vs Cubic Spline Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower right')
plt.show()
