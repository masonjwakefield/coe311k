# %% [markdown]
# Libraries

# %%
import numpy as np
import time

# %% [markdown]
# Jacobi

# %%
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %% [markdown]
# Gauss-Seidel

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        
        x = x_new
    return x, max_iterations

# %% [markdown]
# First matrix

# %%
A = np.array([

[0.582745, 0.48 , 0.10 , 0.  , 0.  ],
[0.48 , 1.044129, 0.46 , 0.10 , 0.  ],
[0.10 , 0.46 , 1.10431 , 0.44 , 0.10 ],
[0.  , 0.10 , 0.44 , 0.963889, 0.42 ],
[0.  , 0.  , 0.10 , 0.42 , 0.522565]], dtype=float)

b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

# %% [markdown]
# Using Jacobi...

# %%
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.perf_counter()

runtime = end - start

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Runtime: {runtime:.6e} seconds")
# Out:
# Solution: [0.34253948 0.34219824 0.34215212 0.34233398 0.34277892]
# Iterations: 100
# Runtime: 1.090932e-02 seconds

# %% [markdown]
# Using Gauss-Seidel

# %%
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.perf_counter()

runtime = end - start

print(f"Gauss-Seidel Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Runtime: {runtime:.6e} seconds")
# Out:
# Gauss-Seidel Solution: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# Iterations: 20
# Runtime: 3.006158e-03 seconds

# %% [markdown]
# Second matrix

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1])

# %% [markdown]
# Using Jacobi...

# %%
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.perf_counter()

runtime = end - start

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Runtime: {runtime:.6e} seconds")
# Out:
# Solution: [1 0]
# Iterations: 1
# Runtime: 7.677232e-04 seconds

# %% [markdown]
# Using Gauss-Seidel

# %%
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.perf_counter()

runtime = end - start

print(f"Gauss-Seidel Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Runtime: {runtime:.6e} seconds")
# Out:
# Gauss-Seidel Solution: [1 0]
# Iterations: 1
# Runtime: 4.992369e-04 seconds

# %% [markdown]
# Third matrix

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1.0001])

# %% [markdown]
# Using Jacobi...

# %%
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.perf_counter()

runtime = end - start

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Runtime: {runtime:.6e} seconds")
# Out:
# Solution: [0.         0.00498727]
# Iterations: 100
# Runtime: 5.511819e-03 seconds

# %% [markdown]
# Using Gauss-Seidel

# %%
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

start = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.perf_counter()

runtime = end - start

print(f"Gauss-Seidel Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Runtime: {runtime:.6e} seconds")
# Out:
# Gauss-Seidel Solution: [0.99014933 0.00994967]
# Iterations: 100
# Runtime: 7.002563e-03 seconds
