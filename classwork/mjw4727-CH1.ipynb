# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-100, 100, 41)
y = x*x

# %%
plt.subplot(2, 2, 1)
plt.scatter(x, y)
plt.subplot(2, 2, 2)
plt.plot(x, y, 'r')
plt.subplot(2, 2, 3)
plt.hist(y, 20)
plt.subplot(2, 2, 4)
plt.step(x, y, 'y')
