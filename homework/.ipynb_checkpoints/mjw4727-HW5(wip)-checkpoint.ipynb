# %% [markdown]
# Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Randomly generating line, logging m & c

# %%
truem = 5 * rng.random()
truec = 5 * rng.random()

print(f"true m: {truem}")
print(f"true c: {truec}")

X = np.arange(0,1,.01)
rand = rng.random(100)
rand = 2*(rand-0.5)
Y = truem*X+truec+rand
# Out:
# true m: 3.302515493265444
# true c: 3.471405398244396

# %% [markdown]
# # Using Numpy Least Squares Algorithm

# %% [markdown]
# Calculating using previous code

# %%
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 3.5105457536548217, Intercept: 3.3988984814883363

# %% [markdown]
# Plotting

# %%
plt.scatter(X,Y,5,"r")
plt.plot(X,m*X+c)
plt.title("Least Squares Regression Line")
plt.show()

# %% [markdown]
# Printing residuals

# %%
resid = Y-(m*X+c)
print(resid)
# Out:
# [ 7.35601928e-01  8.06534667e-01 -2.27430482e-01 -5.14298275e-01
#  -8.71383501e-01 -5.39439360e-01 -3.50920328e-01  3.40032967e-02
#   6.76625014e-01 -6.75029249e-01 -6.21368587e-02  6.52958191e-01
#   1.01453708e+00  1.95489579e-01 -6.01901057e-01  2.30436590e-01
#  -5.89298602e-01  8.45155175e-01 -3.38474110e-01  2.95104849e-01
#  -8.86467966e-01  5.00935375e-02  3.08749801e-01 -6.10525601e-01
#  -6.14057710e-01  7.52985564e-01  4.97610030e-01  4.59617994e-01
#   7.54010680e-01 -1.36894439e-01 -1.43532275e-01 -2.89983251e-01
#  -2.10656056e-01 -6.99907272e-01  6.75932761e-01 -3.39115873e-01
#   2.95090811e-01 -3.68731353e-01 -2.13943168e-01 -8.22073330e-01
#   4.82828271e-02  2.37959757e-01 -4.70830419e-01  7.38390897e-01
#  -5.41167007e-01 -4.59971999e-01  7.10640152e-01 -2.18647555e-01
#  -3.13650332e-01  1.54450043e-01 -4.79728711e-01  8.75122084e-01
#  -8.56119102e-01 -8.85220940e-01  4.89641760e-01  6.03350772e-01
#   3.44941987e-01  4.34654031e-01  4.29671463e-01  1.22751856e-01
#   6.81921046e-01  2.04465920e-01  2.93198374e-01 -1.03484872e+00
#  -6.84354240e-01  5.75993124e-01 -8.28053411e-01 -6.77914116e-01
#  -3.14896865e-01 -5.55620267e-01  6.31115264e-01  6.34776100e-01
#   1.78391392e-01  3.99647641e-01 -4.76684058e-04  7.86294504e-01
#   3.21373773e-01 -8.47704386e-01  6.63594865e-01  4.33383614e-01
#  -3.01301481e-01 -7.14260185e-01 -5.03551724e-01  7.06300997e-01
#   7.10116174e-01 -5.01511358e-01  5.54419524e-01  3.22029548e-01
#  -8.81008476e-01 -1.09086747e+00  6.93973204e-02  6.82428943e-01
#   8.43856332e-01  6.56391507e-01  8.09878869e-01 -3.78524452e-01
#  -1.09365431e+00  5.71262220e-01 -5.18147118e-01 -9.42400783e-01]

# %% [markdown]
# Printing max and min residuals

# %%
print(f"Max residual: {resid.max()}")
print(f"Min residual: {resid.min()}")
# Out:
# Max residual: 1.0145370784440706
# Min residual: -1.093654310857139

# %% [markdown]
# # Using My Least Squares algorithm

# %% [markdown]
# Coding the algorithm

# %%
def
